# %% [markdown]
# <a href="https://colab.research.google.com/github/dmhenaopa/EDCO/blob/main/Semana2/Sesion3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Aprender a conectarnos al drive**
#
# Desde colab para escribir y leer archivos del drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True) # Montar el disco para acceso al drive
# Out:
# Mounted at /content/drive

# %%
# Librerias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Sistema operativo
import os

# %%
# Directorio actual
# !pwd # En python, llamar comando de linux con signos de admiración !
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# pwd: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected

# %%
# Listar el contenido en la carpeta
# !ls
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# ls: cannot open directory '.': Transport endpoint is not connected

# %%
# Movernos de carpeta
ruta = "/content/drive/MyDrive/EDCO_IntroCienciaDatos/Semana2"
os.chdir(ruta)

# %%
# !pwd # Comprobar la carpeta
# Out:
# /content/drive/MyDrive/EDCO_IntroCienciaDatos/Semana2

# %% [markdown]
# Necesitamos reservar el espacio para poder escribir dentro archivos y carpetas

# %%
# Crear carpeta de salida
salida = "Carpeta_salida"
os.makedirs(salida, exist_ok = True) # True para no reescribir la carpeta en caso de que exista

# %%
# Crear 40 carpetas en la carpeta de salida - revisar el lugar en donde esta creandolas, este no es
# !pwd

for i in range(0, 40):
  subcarpeta = 'sub_{}'.format(i)

  print('Creando carpeta:', subcarpeta)
  os.makedirs(subcarpeta, exist_ok = True)
# Out:
# /content/drive/MyDrive/EDCO_IntroCienciaDatos/Semana2
# Creando carpeta: sub_0
# Creando carpeta: sub_1
# Creando carpeta: sub_2
# Creando carpeta: sub_3
# Creando carpeta: sub_4
# Creando carpeta: sub_5
# Creando carpeta: sub_6
# Creando carpeta: sub_7
# Creando carpeta: sub_8
# Creando carpeta: sub_9
# Creando carpeta: sub_10
# Creando carpeta: sub_11
# Creando carpeta: sub_12
# Creando carpeta: sub_13
# Creando carpeta: sub_14
# Creando carpeta: sub_15
# Creando carpeta: sub_16
# Creando carpeta: sub_17
# Creando carpeta: sub_18
# Creando carpeta: sub_19
# Creando carpeta: sub_20
# Creando carpeta: sub_21
# Creando carpeta: sub_22
# Creando carpeta: sub_23
# Creando carpeta: sub_24
# Creando carpeta: sub_25
# Creando carpeta: sub_26
# Creando carpeta: sub_27
# Creando carpeta: sub_28
# Creando carpeta: sub_29
# Creando carpeta: sub_30
# Creando carpeta: sub_31
# Creando carpeta: sub_32
# Creando carpeta: sub_33
# Creando carpeta: sub_34
# Creando carpeta: sub_35
# ...

# %% [markdown]
# Revisar nuestras bases de datos

# %%
BaseDatos = {
    1001: { 'Nombre': 'Pepito', 'Apellido': 'Perezito', 'Edad': 35, 'Genero': 'M' },
    1002: { 'Nombre': 'Pepita', 'Apellido': 'Perezita', 'Edad': 25, 'Genero': 'F' },
    1003: { 'Nombre': 'Pepite', 'Apellido': 'Perezite', 'Edad': 28, 'Genero': 'M' },
}

# %%
# Primer dataframe
df = pd.DataFrame.from_dict(BaseDatos, orient='index')
df
# Out:
#       Nombre  Apellido  Edad Genero
# 1001  Pepito  Perezito    35      M
# 1002  Pepita  Perezita    25      F
# 1003  Pepite  Perezite    28      M

# %%
# Elegir una columna de los datos
df['Edad']

# %%
# Pandas básico
df.index.name = 'ID'
df
# Out:
#       Nombre  Apellido  Edad Genero
# ID
# 1001  Pepito  Perezito    35      M
# 1002  Pepita  Perezita    25      F
# 1003  Pepite  Perezite    28      M

# %%
# Podemos convertir el ID en una columna
df = df.reset_index()
df
# Out:
#      ID  Nombre  Apellido  Edad Genero
# 0  1001  Pepito  Perezito    35      M
# 1  1002  Pepita  Perezita    25      F
# 2  1003  Pepite  Perezite    28      M

# %%
# Visualizar los dataframe
df.head(2)
# Out:
#      ID  Nombre  Apellido  Edad Genero
# 0  1001  Pepito  Perezito    35      M
# 1  1002  Pepita  Perezita    25      F

# %%
# Dimensiones - R1 nombre, R2 apellido, R3 edad, R4 Genero - El id no es explicativo entonces realmente no va
df.shape # Esto da un (3, 5) - 3 entradas, 5 columnas - Dimension de la matriz o tamaño
# Out:
# (3, 5)
