# %% [markdown]
# <a href="https://colab.research.google.com/github/dmhenaopa/EDCO/blob/main/ejercicios_adicionales/negocio_crochet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Información de ventas de la empresa de amigurumis en crochet  🧶

# %%
### Datos disponibles
### productos disponibles, ventas, clientes, tiempo de producción, costos de materia prima, compradores,

### Tabla 1: Productos disponibles
productos = {}
producto_id = [ 0001, 0002, 0003, 0004, 0005 ]
nombre = [ 'Llavero gallinita sencillo', 'LLavero gallinita detallado', 'Rata porta cerveza', 'Llavero gaviota', 'Ramón Burro' ]
tamaño = [] # En centimetros
materiales = []
tiempo_de_produccion = []
materia_prima = []
costo_materia_prima = []
cantidad_materia_prima = []

# %%
### Tabla 2: Materiales
materiales = {}
materiales_id = []
nombre = []
presentacion = []
costo = []
marca = []
referencia = []

# %%
### Tabla 3: Ventas
ventas = {}
venta_id = []
cliente_id = []
status = []

# %%
### Tabla 4: Clientes
clientes = {}
cliente_id = []
nombre = []
apellido = []
identificacion = []
telefono = []
email = []
venta_id = []
